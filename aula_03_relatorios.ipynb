# %% [markdown]
# # Atividade: Construindo um relatório com IA
#
# Nesta segunda parte da aula, você vai usar uma inteligência artificial (Claude, ChatGPT ou Gemini) para aprofundar a análise que fizemos no notebook. Ao final, você terá um relatório completo, montado neste próprio notebook, em células de texto.
#
# **Antes de começar:**
#
# 1. Abra uma conta gratuita em claude.ai, chat.openai.com ou gemini.google.com
# 2. Envie o arquivo `student_habits_performance.csv` no chat da IA
# 3. Neste notebook, crie uma célula de texto com o título: **Relatório de Análise — Hábitos e Desempenho dos Alunos**
#
# > **Observação importante:** esta base é fictícia, pode enviar sem problemas. No trabalho real, nunca envie dados de pessoas reais para uma IA pública.
#
# ---
#
# ## Parte 1
#
# Faça as três perguntas abaixo, na ordem, para a mesma IA. Observe como a resposta melhora a cada versão.
#
# **Pergunta 1 (apenas a pergunta):**
#
# ```
# Qual hábito mais influencia a nota dos alunos?
#
# ```
#
# **Pergunta 2 (a pergunta com contexto):**
#
# ```
# Esta base tem 1000 alunos, com hábitos (horas de estudo, sono, redes sociais, exercício) e a nota final no exame (exam_score). Analise quais hábitos mais influenciam a nota e mostre os números que comprovam.
# ```
#
# **Pergunta 3 (contexto, persona e formato de resposta):**
#
# ```
# Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola.
# ```
#
# No relatório, crie a seção **"1. Engenharia de Prompt"** e responda: o que mudou da primeira para a terceira resposta? Qual delas você usaria num trabalho real? Cole a melhor das três respostas.
#
# ---
#
# ## Parte 2
#
# O heatmap que fizemos usou apenas as colunas numéricas. A base também tem colunas de texto que o código não analisou. Use o estilo da Pergunta 3 (com contexto e persona) para investigar pelo menos três das perguntas abaixo:
#
# ```
# A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo.
# ```
#
# ```
# Alunos com trabalho de meio período (part_time_job) vão pior nas notas?
# ```
#
# ```
# A escolaridade dos pais (parental_education_level) tem relação com o desempenho?
# ```
#
# ```
# Existe uma quantidade ideal de horas de sono para tirar as melhores notas?
# ```
#
# No relatório, crie a seção **"2. Novas análises"** e cole os insights que achou mais interessantes.
#
# **Atenção:** alguns desses fatores quase não mudam a nota. Isso também é uma descoberta, pois mostra que nem tudo que imaginamos ser importante realmente é.
#
# ---
#
# ## Parte 3
#
# Faça a seguinte pergunta para a IA:
#
# ```
# Por que os alunos mais velhos desta base tiraram notas muito mais altas?
# ```
#
# Agora confira no notebook: a idade tem relação com a nota? Observe como a IA respondeu. Ela inventou uma explicação ou avisou que não havia relação nos dados?
#
# No relatório, crie a seção **"3. Cuidados e Ética no uso da IA"** e escreva, com suas palavras, o que aconteceu e por que é perigoso confiar cegamente na IA no trabalho.
#
# Antes de finalizar, confira um dos números que a IA forneceu em qualquer uma das partes, usando o seu notebook. Um bom analista sempre confere.
#
# ---
#
# ## Entrega
#
# Ao final, seu notebook deve conter as células de código feitas em aula e as três seções do relatório em Markdown:
#
# - Relatório de Análise — Hábitos e Desempenho dos Alunos
# - 1. Engenharia de Prompt
# - 2. Novas análises
# - 3. Cuidados e Ética no uso da IA
#
# Salve e envie pelo Classroom.

# %% [markdown]
# ## **Relatório de Análise — Hábitos e Desempenho dos Alunos**

# %% [markdown]
# Qual hábito mais influencia a nota dos alunos?
# # CLAUDE.AI:
# Vários hábitos podem influenciar a nota de um aluno — horas de estudo, qualidade do sono, uso de redes sociais, prática de exercícios, entre outros. De forma geral, o tempo dedicado aos estudos tende a ser apontado como o fator mais relevante, mas isso pode variar bastante dependendo do grupo de alunos analisado e de outros fatores como saúde mental e disciplina de estudo.
#
# # GEMINI.AI(PRO):
# A análise dos dados revela que o hábito que mais influencia a nota dos alunos é a **quantidade de horas de estudo por dia**. O tempo dedicado aos estudos possui uma correlação positiva muito forte com as notas, destacando-se significativamente em relação a todos os outros hábitos monitorados.
#
# Abaixo está o impacto dos hábitos na nota, ordenados do maior para o menor impacto:
#
# * **Horas de Estudo por Dia:** Possui a correlação positiva mais forte com a nota.
# * **Frequência de Exercícios e Horas de Sono:** Possuem um impacto positivo fraco.
# * **Taxa de Frequência nas Aulas:** Possui um impacto positivo muito fraco.
# * **Horas em Redes Sociais e Horas de Netflix:** Apresentam uma correlação negativa, ou seja, tendem a diminuir a nota do aluno, mas o impacto é considerado fraco.
# * **Qualidade da Dieta e Atividades Extracurriculares:** Não apresentam variações relevantes nas médias das notas dos alunos.
#
# # Maritaca.AI:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🎯 O hábito que mais influencia a nota dos alunos: horas de estudo por dia
# A análise de regressão múltipla (controlando todos os hábitos simultaneamente) mostra que cada hora adicional de estudo por dia aumenta a nota em ~9,6 pontos — de longe o maior efeito observado.
#
# Ranking dos hábitos por impacto na nota (coeficiente da regressão múltipla)

# %% [markdown]
# ![tabela.png](attachment:tabela.png)

# %% [markdown]
# ## 🎯 O hábito que mais influencia a nota dos alunos: **horas de estudo por dia**
#
# A análise de regressão múltipla (controlando todos os hábitos simultaneamente) mostra que **cada hora adicional de estudo por dia aumenta a nota em ~9,6 pontos** — de longe o maior efeito observado.
#
# ### Ranking dos hábitos por impacto na nota (coeficiente da regressão múltipla)
#
# | Hábito | Impacto por unidade | Direção | Significância |
# |---|---|---|---|
# | 🥇 **Horas de estudo/dia** | **+9,6 pontos por hora** | ✅ Positivo | p < 0,001 |
# | 🥈 Saúde mental (escala 1-10) | +1,95 pontos por ponto | ✅ Positivo | p < 0,001 |
# | 🥉 Horas de sono | +2,0 pontos por hora | ✅ Positivo | p < 0,001 |
# | 4º Exercício físico (frequência) | +1,45 pontos por unidade | ✅ Positivo | p < 0,001 |
# | 5º Horas de redes sociais | −2,62 pontos por hora | ❌ Negativo | p < 0,001 |
# | 6º Horas de Netflix | −2,28 pontos por hora | ❌ Negativo | p < 0,001 |
# | 7º Frequência escolar (%) | +0,14 pontos por ponto percentual | ✅ Positivo | p < 0,001 |
# | 8º Trabalho de meio período | +0,24 pontos (não significativo) | — | p = 0,57 |
# | 9º Qualidade da dieta | −0,29 pontos (não significativo) | — | p = 0,21 |
# | 10º Atividades extracurriculares | −0,03 pontos (não significativo) | — | p = 0,93 |
#
# ### Principais conclusões
#
# 1. **Horas de estudo é o fator dominante**, com um coeficiente ~5× maior que o segundo colocado. A correlação simples com a nota é de **0,825** — extremamente forte.
#
# 2. **Tempo excessivo em telas prejudica**: cada hora extra em redes sociais ou Netflix reduz a nota em ~2,5 pontos. Esses efeitos permanecem significativos mesmo controlando pelo tempo de estudo.
#
# 3. **Saúde mental e sono são surpreendentemente relevantes**: ambos têm impacto comparável ao de fatores tradicionais como frequência escolar, sugerindo que o bem-estar do aluno é um pilar do desempenho acadêmico.
#
# 4. **Fatores demográficos e de contexto** (trabalho, dieta, extracurriculares) **não mostraram efeito significativo** nesta amostra quando controlados pelos demais hábitos.
#
# > ⚠️ *Os coeficientes representam o efeito isolado de cada variável mantendo as demais constantes — ou seja, medem o impacto "puro" de cada hábito.*

# %% [markdown]
# Pergunta 2:
# # GEMINI.AI:
#
# A análise estatística da base de dados confirma que a **quantidade de horas de estudo por dia** é, de longe, o hábito que mais influencia a nota final do aluno.
#
# Para comprovar isso, calculamos a **correlação** entre cada hábito e a nota no exame (`exam_score`). Na estatística, a correlação varia de -1 a 1, onde valores próximos a 1 indicam forte impacto positivo (aumenta a nota), valores próximos a -1 indicam impacto negativo (diminui a nota), e valores próximos a 0 indicam que quase não há relação.
#
# Aqui estão os números exatos extraídos da base de 1000 alunos:
#
# ### 1. Maior Impacto Positivo (O que aumenta a nota)
#
# * **Horas de Estudo por Dia:** **0,825**
# * *Interpretação:* Apresenta uma correlação fortíssima. É o principal fator determinante para o sucesso no exame.
#
# * **Frequência de Exercícios Físicos:** **0,160**
# * *Interpretação:* Apresenta um impacto positivo leve. Alunos que se exercitam tendem a ter um desempenho ligeiramente melhor.
#
# * **Horas de Sono:** **0,121**
# * *Interpretação:* Impacto positivo leve. Dormir bem ajuda, mas na prática tem um peso estatístico menor do que estudar ou fazer exercícios.
#
# ### 2. Impactos Negativos (O que diminui a nota)
#
# * **Horas em Redes Sociais:** **-0,166**
# * *Interpretação:* Impacto negativo leve a moderado. Quanto mais tempo o aluno passa nas redes sociais, menor tende a ser a sua nota.
#
#
# * **Horas de Netflix:** **-0,171**
# * *Interpretação:* O maior impacto negativo entre os hábitos analisados. O consumo de streaming rouba tempo de estudo e prejudica o resultado final de forma mais acentuada do que as redes sociais.
#
# **Conclusão dos Números:**
# A matemática dos dados mostra que não há atalhos. O peso de estudar diariamente (0,825) é cerca de **5 vezes maior** do que qualquer outro hábito saudável (como exercícios ou sono) e sobrepõe facilmente os impactos negativos das distrações digitais.

# %% [markdown]
# # CLAUDE.AI:
# Agora com contexto sobre a base, calculando a correlação de cada hábito com `exam_score`:
#
# Analisando os 1000 alunos, os hábitos com maior influência na nota final são:
#
# - **Horas de estudo por dia**: correlação de **0,83** com a nota — de longe o fator mais forte, confirmando a relação direta entre tempo de estudo e desempenho.
# - **Saúde mental (mental_health_rating)**: correlação de **0,32** — segundo fator mais relevante.
# - **Frequência de exercício**: correlação de **0,16** — impacto positivo, porém moderado.
# - **Horas de sono**: correlação de **0,12** — impacto positivo, mas fraco.
# - **Uso de redes sociais**: correlação de **-0,17** — quanto mais tempo em redes sociais, menor a nota.
# - **Horas de Netflix**: correlação de **-0,17** — mesmo padrão negativo das redes sociais.
#
# Em resumo: estudo é o hábito que mais explica a nota, redes sociais e Netflix atrapalham moderadamente, e sono/exercício ajudam pouco em comparação ao estudo.
#
# Repara que essa resposta já usa números reais da base (porque agora dei contexto), mas ainda está em tom "cru", sem estar formatada para um público específico — é a diferença entre a Pergunta 2 e a Pergunta 3. Quer que eu siga para a Pergunta 3 também?

# %% [markdown]
# # MARITACA.AI:
#
# Com base na análise estatística dos 1.000 alunos da base, aqui estão os números que comprovam quais hábitos mais influenciam a nota final (exam_score):

# %% [markdown]
# ![tabela (2).png](<attachment:tabela (2).png>)

# %% [markdown]
# A correlação de 0,825 entre horas de estudo e nota é excepcional — em ciências sociais, valores acima de 0,7 são considerados muito raros e indicam uma relação quase determinística

# %% [markdown]
# 🧪 Regressão múltipla — efeito isolado de cada hábito
# Controlando todos os hábitos simultaneamente (efeito ceteris paribus):

# %% [markdown]
# ![tabela (4).png](<attachment:tabela (4).png>)

# %% [markdown]
# 📈 Visualização — impacto padronizado de cada hábito

# %% [markdown]
# ![coeficientes_habitos.png](attachment:coeficientes_habitos.png)

# %% [markdown]
# ![correlacao_habitos.png](attachment:correlacao_habitos.png)

# %% [markdown]
# ✅ Conclusão
# Horas de estudo por dia é, de longe, o hábito mais determinante para a nota, com:
#
# Correlação de 0,825 (r² ≈ 0,68 → 68% da variação na nota é explicada pelo tempo de estudo)
# Coeficiente de +9,58 pontos por hora em regressão múltipla
# p-valor = 0 (significância máxima — a probabilidade de esse resultado ser ao acaso é praticamente zero)
# Em segundo plano, hábitos de bem-estar (saúde mental, sono, exercício) e tempo de tela (redes sociais, Netflix) têm efeitos reais, porém muito menores — cerca de 5 a 6× menores que o estudo. Fatores como trabalho de meio período, dieta e atividades extracurriculares não apresentaram efeito estatisticamente significativo nesta amostra.

# %% [markdown]
# # PERGUNTA 3:
# Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola.

# %% [markdown]
# ### GEMINI.AI:

# %% [markdown]
# Prezada Direção,
#
# Apresento a seguir a análise dos dados referentes aos 1.000 alunos da nossa base. O objetivo deste levantamento foi identificar, de forma puramente estatística, quais comportamentos cotidianos mais interferem no desempenho acadêmico (nota final) dos estudantes.
#
# Para medir esse impacto, utilizamos um indicador chamado **correlação**. Ele funciona como um "termômetro de influência", variando de -1 a 1. Valores positivos indicam hábitos que aumentam a nota, enquanto valores negativos indicam hábitos que a diminuem. Quanto mais distante do zero, mais forte é o impacto.
#
# Abaixo, detalho os 3 hábitos que mais impactam os resultados dos nossos alunos, ordenados do maior para o menor grau de influência:
#
# ### 1. Horas de Estudo por Dia (O Grande Diferencial)
#
# * **Índice de Impacto:** **+0,825**
# * **O que a estatística nos diz:** Este é, com uma margem gigantesca, o fator mais determinante para o sucesso do aluno. O índice de 0,825 indica uma relação positiva **extremamente forte**. Na prática, os dados provam que a rotina de estudo fora da sala de aula é o motor principal das notas altas, superando largamente o impacto de qualquer outro hábito de saúde, presença ou lazer.
#
# ### 2. Tempo de Consumo de Streaming (Netflix)
#
# * **Índice de Impacto:** **-0,171**
# * **O que a estatística nos diz:** O segundo hábito de maior peso na base age como um detrator do desempenho. O sinal negativo indica que quanto mais tempo o aluno passa consumindo séries e filmes, menor tende a ser a sua nota final. Esse excesso de tela "rouba" o tempo e o foco que deveriam ser direcionados ao estudo produtivo.
#
# ### 3. Tempo Gasto em Redes Sociais
#
# * **Índice de Impacto:** **-0,167**
# * **O que a estatística nos diz:** Assim como o consumo de streaming, o uso excessivo de redes sociais também puxa a nota para baixo de maneira consistente. O impacto é quase idêntico ao da Netflix, o que evidencia um padrão comportamental claro na nossa base de alunos.
#
# ---
#
# ### Conclusão e Recomendação Estratégica
#
# Os números revelam uma realidade objetiva: **não há atalhos ou substitutos para o tempo de estudo (0,825)**. Ele é cerca de cinco vezes mais impactante do que outros hábitos positivos (como exercícios ou sono regular).
#
# Além disso, os maiores vilões do desempenho acadêmico dos nossos alunos não estão relacionados à infraestrutura ou à alimentação, mas sim à **concorrência do tempo com o entretenimento digital** (streaming e redes sociais).
#
# Recomenda-se que a escola invista em iniciativas de conscientização sobre **gestão de tempo e higiene digital** para os alunos e famílias, pois a redução dessas distrações associada à criação de uma rotina de estudos em casa trará os maiores ganhos possíveis para as médias da instituição.

# %% [markdown]
# # CLAUDE.AI:
# Como analista de dados educacionais, apresentando para a direção da escola:
# Prezada direção,
# Analisamos os hábitos de 1.000 alunos para entender o que mais impacta o desempenho no exame final. Os três fatores com maior peso foram:
# 1. Horas de estudo diárias — este é, isoladamente, o fator mais decisivo (correlação de 0,83 com a nota). Quanto mais tempo o aluno dedica ao estudo por dia, maior tende a ser sua nota, de forma consistente em toda a base.
# 2. Saúde mental — o segundo fator mais relevante (correlação de 0,32). Alunos que relatam melhor saúde mental apresentam desempenho mais alto, o que sugere que o bem-estar emocional não é secundário ao aprendizado — ele o sustenta.
# 3. Tempo em redes sociais e streaming (Netflix) — ambos mostraram relação inversa com a nota (correlação de -0,17 cada). Mais tempo nessas atividades está associado a notas mais baixas.
# Recomendação: o maior potencial de melhoria está em programas de apoio ao estudo estruturado e de suporte à saúde mental dos alunos — o efeito desses dois fatores é muito superior ao de simplesmente tentar restringir o uso de redes sociais.

# %% [markdown]
# ### MARITACA.AI:
#
# 📋 Relatório Executivo — Análise de Hábitos e Desempenho Acadêmico
# Base analisada: 1.000 alunos | Variável-alvo: Nota final no exame (exam_score)
#
# 🔍 Os 3 hábitos que mais impactam a nota dos alunos
# Após isolar o efeito de cada hábito simultaneamente (controlando por idade, gênero e demais variáveis), identificamos os três fatores com maior peso no desempenho. Os números abaixo indicam quanto a nota muda quando o hábito muda em uma unidade:
#
# 🥇 1º — Horas de estudo por dia
# Impacto: +9,6 pontos na nota por hora adicional de estudo
#
# Este é, de longe, o hábito mais determinante. A diferença entre um aluno que estuda 1 hora por dia e outro que estuda 4 horas por dia equivale a ~29 pontos na nota — praticamente a diferença entre reprovação e aprovação com folga.
#
# O que isso significa para a escola:
#
# Cada hora extra de estudo estruturado que conseguirmos promover nos alunos se traduz diretamente em ganho expressivo de desempenho.
# Programas de monitoria, plantões de dúvidas e orientação de estudo têm potencial de retorno muito alto.
# 🥈 2º — Tempo em redes sociais (por dia)
# Impacto: −2,6 pontos na nota por hora adicional
#
# O uso excessivo de redes sociais tem efeito negativo consistente e estatisticamente robusto. Um aluno que passa 4 horas por dia em redes sociais perde, em média, ~10 pontos em relação a um colega que passa 1 hora — mesmo controlando pelo tempo de estudo.
#
# O que isso significa para a escola:
#
# A distração digital compete diretamente com o tempo e a qualidade do estudo.
# Iniciativas de educação digital e gestão do tempo podem recuperar parcela significativa desse prejuízo.
# Vale considerar políticas de uso de celular em sala e campanhas de conscientização junto às famílias.
# 🥉 3º — Tempo em Netflix/streaming (por dia)
# Impacto: −2,3 pontos na nota por hora adicional
#
# O consumo de conteúdo de entretenimento em vídeo segue o mesmo padrão negativo das redes sociais. Cada hora extra assistindo séries/filmes reduz a nota de forma mensurável.
#
# O que isso significa para a escola:
#
# O tempo de tela recreativo (redes sociais + streaming) combinado representa um impacto de até ~5 pontos por hora na direção negativa.
# Alunos que consomem 3+ horas diárias de entretenimento em tela estão, na prática, abrindo mão de ~15 pontos na nota — o equivalente a quase duas questões inteiras em um exame padrão.

# %% [markdown]
# ![tabela (5).png](<attachment:tabela (5).png>)

# %% [markdown]
# Resumo para decisão: Focar simultaneamente em (1) ampliar o tempo de estudo estruturado e (2) reduzir o tempo de tela recreativo é a estratégia com maior probabilidade de elevar o desempenho coletivo da escola. O hábito de estudo sozinho explica 68% da variação nas notas desta amostra — o que reforça que a escola tem, em mãos, o principal fator de transformação.

# %% [markdown]
# # PARTE 2

# %% [markdown]
# ### GEMINI.AI:
#
# Como analista de dados, posso afirmar que, com base nas estatísticas desta amostra, a qualidade da dieta relatada não faz uma diferença significativa na nota final dos alunos.
#
# Embora o senso comum sugira que uma alimentação melhor leve a um desempenho acadêmico superior, os números mostram que a variação entre os grupos é mínima (pouco mais de 2 pontos de diferença) e não segue uma lógica perfeitamente direta.
#
# Abaixo estão as médias exatas das notas (exam_score) agrupadas pela qualidade da dieta (diet_quality), junto com o volume de alunos em cada categoria:

# %% [markdown]
# Como analista de dados, posso afirmar que, com base nas estatísticas desta amostra, a qualidade da dieta relatada **não faz uma diferença significativa** na nota final dos alunos.
#
# Embora o senso comum sugira que uma alimentação melhor leve a um desempenho acadêmico superior, os números mostram que a variação entre os grupos é mínima (pouco mais de 2 pontos de diferença) e não segue uma lógica perfeitamente direta.
#
# Abaixo estão as médias exatas das notas (`exam_score`) agrupadas pela qualidade da dieta (`diet_quality`), junto com o volume de alunos em cada categoria:
#
# | Qualidade da Dieta | Nota Média | Total de Alunos |
# | --- | --- | --- |
# | **Razoável (Fair)** | 70,43 | 437 |
# | **Boa (Good)** | 69,37 | 378 |
# | **Ruim (Poor)** | 68,13 | 185 |
#
# ### Conclusão Analítica
#
# * **Impacto Irrelevante:** A diferença entre a maior média (70,43) e a menor (68,13) é de apenas 2,3 pontos. Em termos de correlação estatística e impacto acadêmico real, esse valor é praticamente nulo.
# * **Ausência de Tendência Linear:** Curiosamente, o grupo de alunos que classificou sua dieta como "Razoável" obteve uma média levemente superior à dos alunos com dieta "Boa". Isso indica que a variável da alimentação sofre ruído de outros fatores muito mais determinantes (como o tempo dedicado aos estudos) e não serve como um bom previsor para as notas nesta instituição.

# %% [markdown]
# ### CLAUDE.AI:
# Como analista de dados educacionais, apresentando para a direção da escola:
#
# Prezada direção,
#
# Avaliamos se a qualidade da alimentação relatada pelos alunos (diet_quality) está associada ao desempenho no exame. A nota média por grupo foi:
#
# - **Dieta "Fair" (regular)**: 70,4 pontos (437 alunos)
# - **Dieta "Good" (boa)**: 69,4 pontos (378 alunos)
# - **Dieta "Poor" (ruim)**: 68,1 pontos (185 alunos)
#
# A diferença entre o grupo de melhor e pior média é de apenas cerca de 2,3 pontos — pequena diante da escala de notas. Além disso, chama atenção que o grupo "Fair" (regular) teve a média mais alta, não o "Good" — ou seja, não existe uma progressão clara de "quanto melhor a dieta, maior a nota".
#
# **Conclusão:** a qualidade da dieta, isoladamente, não parece ser um fator determinante para o desempenho nesta base. Recomendo não priorizar esse fator em iniciativas de melhoria de desempenho, dado o impacto muito mais forte já identificado em estudo e saúde mental.

# %% [markdown]
# ### MARITACA.AI:
# ![nota_por_dieta (2).png](<attachment:nota_por_dieta (2).png>)

# %% [markdown]
# 🍎 Qualidade da dieta vs. nota: o que os dados mostram
# Média de nota por categoria de dieta

# %% [markdown]
# ![tabela (6).png](<attachment:tabela (6).png>)

# %% [markdown]
# Análise estatística
# Diferença entre os grupos: 2,3 pontos (70,4 vs. 68,1 — razoável vs. ruim)
# ANOVA (teste de diferença entre grupos): p = 0,28 → não significativo
# ⚠️ Uma diferença só é considerada estatisticamente relevante quando p < 0,05. Com p = 0,28, a chance de essa variação ser mero acaso é de 28% — portanto, não podemos afirmar que a dieta, por si só, influencia a nota nesta amostra.

# %% [markdown]
# Por que a diferença é tão pequena?
# Há um fator de confusão importante: alunos com dieta ruim também estudam menos.

# %% [markdown]
# ![tabela (8).png](<attachment:tabela (8).png>)

# %% [markdown]
# O grupo com dieta ruim estuda, em média, 0,3 hora a menos por dia que o grupo razoável. Como cada hora de estudo vale ~9,6 pontos, essa diferença de 0,3h (~2,9 pontos) já explica quase toda a lacuna de 2,3 pontos observada na nota.

# %% [markdown]
#  ![tabela (9).png](<attachment:tabela (9).png>)

# %% [markdown]
# Em resumo: a dieta não é um preditor independente da nota nesta base. O hábito que realmente separa os alunos com nota alta dos demais continua sendo o tempo dedicado ao estudo.

# %% [markdown]
# ### Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score).Alunos com trabalho de meio período (part_time_job) vão pior nas notas?

# %% [markdown]
# ### GEMINI.AI:
#
# Como analista de dados, posso afirmar que alunos que possuem um trabalho de meio período vão **levemente pior** nas notas, mas a diferença é tão pequena que **não representa um impacto grave** no desempenho acadêmico geral.
#
# Ao cruzar a variável de trabalho de meio período (`part_time_job`) com as notas dos exames (`exam_score`), os números revelam uma queda quase marginal na média.
#
# Abaixo estão os dados exatos extraídos da nossa base de 1.000 alunos:
#
# | Situação de Trabalho | Nota Média | Total de Alunos | Desvio Padrão |
# | --- | --- | --- | --- |
# | **Não trabalha (No)** | 69,84 | 785 | 16,98 |
# | **Trabalha (Yes)** | 68,74 | 215 | 16,58 |
#
# ### Conclusão Analítica
#
# * **Diferença Mínima:** A diferença entre a média dos alunos que apenas estudam e dos que também trabalham é de apenas **1,1 ponto**.
# * **Proporção da Amostra:** Cerca de 21,5% da nossa base (215 alunos) concilia os estudos com um trabalho de meio período.
# * **Contexto:** Embora exista uma pequena desvantagem estatística, ela não é o fator que "destrói" a nota do aluno. Como vimos em análises anteriores, o que realmente define a nota final é a quantidade de horas de estudo por dia e o controle de distrações (como redes sociais e streaming). O fato de o aluno trabalhar afeta a nota muito menos do que o tempo gasto na Netflix, por exemplo.

# %% [markdown]
# ### CLAUDE.AI:
#
# Como analista de dados educacionais, apresentando para a direção da escola:
#
# Prezada direção,
#
# Comparamos a nota média de alunos que trabalham meio período com a de quem não trabalha:
#
# - **Sem trabalho de meio período**: 69,8 pontos (785 alunos)
# - **Com trabalho de meio período**: 68,7 pontos (215 alunos)
#
# A diferença é de apenas cerca de 1,1 ponto — bem pequena diante da escala de notas, e muito menor do que o impacto já identificado em horas de estudo ou saúde mental.
#
# **Conclusão:** ter um trabalho de meio período não parece prejudicar significativamente o desempenho nesta base. Não recomendo tratar esse fator como prioridade em ações voltadas à melhoria de notas.

# %% [markdown]
# ### MARITACA.AI:

# %% [markdown]
# ![nota_por_trabalho (2).png](<attachment:nota_por_trabalho (2).png>)

# %% [markdown]
# 💼 Trabalho de meio período vs. desempenho acadêmico
# Média de nota por situação de trabalho

# %% [markdown]
# ![tabela (10).png](<attachment:tabela (10).png>)

# %% [markdown]
# Análise estatística
# Diferença de médias: 1,1 ponto (69,8 vs. 68,7)
# Teste t (p-valor): 0,39 → não significativo
# ⚠️ Com p = 0,39, a probabilidade de essa pequena diferença ser fruto do acaso é de 39% — muito acima do limiar de 5% usado para afirmar significância estatística. Não podemos concluir que ter trabalho de meio período prejudica a nota.

# %% [markdown]
# Por que a intuição falha aqui?
# Muitos esperam que o trabalho tire tempo de estudo, mas os dados mostram:

# %% [markdown]
# ![tabela (11).png](<attachment:tabela (11).png>)

# %% [markdown]
# A diferença de 0,1 hora (6 minutos) de estudo por dia é mínima — e insuficiente para gerar impacto mensurável na nota (cada hora de estudo vale ~9,6 pontos, então 6 minutos valeriam ~1 ponto).

# %% [markdown]
# 📋 Resumo para a direção

# %% [markdown]
# ![tabela (12).png](<attachment:tabela (12).png>)

# %% [markdown]
# Recomendação prática: Em vez de proibir ou desaconselhar o trabalho, a escola pode oferecer orientação de gestão de tempo para alunos trabalhadores, garantindo que mantenham uma rotina de estudo consistente. O dado tranquiliza: o trabalho de meio período, por si só, não é um fator de risco acadêmico nesta população.

# %% [markdown]
# ## Pergunta 3:
# Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score) A escolaridade dos pais (parental_education_level) tem relação com o desempenho?

# %% [markdown]
# ### GEMINI.AI:
#
# Como analista de dados, após cruzar a variável de escolaridade dos pais (`parental_education_level`) com as notas dos exames (`exam_score`), concluo que o nível educacional da família **não possui uma relação direta ou significativa** com o desempenho acadêmico dos alunos nesta base.
#
# Diferente do que se costuma esperar em alguns contextos educacionais (onde uma maior escolaridade familiar impulsiona fortemente as notas), os números revelam que o impacto desse fator é mínimo e não segue uma progressão lógica nesta amostra.
#
# Abaixo estão os dados exatos extraídos da nossa base, agrupados por nível de escolaridade e ordenados pela nota média:
#
# | Escolaridade dos Pais | Nota Média | Total de Alunos | Desvio Padrão |
# | --- | --- | --- | --- |
# | **Graduação (Bachelor)** | 70,27 | 350 | 17,29 |
# | **Não Informado** | 70,03 | 91 | 16,56 |
# | **Ensino Médio (High School)** | 69,55 | 392 | 16,83 |
# | **Mestrado (Master)** | 68,09 | 167 | 16,40 |
#
# ### Conclusão Analítica
#
# * **Variação Estatisticamente Irrelevante:** A diferença entre a maior média (alunos de pais com Graduação, 70,27) e a menor média (alunos de pais com Mestrado, 68,09) é de apenas 2,18 pontos. Essa variação estreita mostra que o fator familiar tem um peso muito baixo na composição do resultado final.
# * **Inversão de Expectativa (Sem Tendência Linear):** Curiosamente, o grupo de alunos cujos pais possuem o maior nível de instrução formal (Mestrado) apresentou a menor nota média do levantamento. Isso quebra completamente a hipótese de que "quanto maior a escolaridade dos pais, maior a nota do aluno".
# * **O Protagonismo do Aluno:** Este resultado reforça a tese levantada em análises anteriores: o desempenho nesta escola é guiado quase que exclusivamente pela **rotina individual do estudante**. O background socioeducacional da família não "salva" a nota de quem estuda pouco, assim como não limita os alunos que vêm de famílias com menor escolaridade, mas que possuem uma forte rotina de estudos em casa.

# %% [markdown]
# ### CLAUDE.AI:
# Como analista de dados educacionais, apresentando para a direção da escola:
#
# Prezada direção,
#
# Avaliamos se o nível de escolaridade dos pais está associado ao desempenho dos alunos. A nota média por grupo foi:
#
# - **Bachelor (graduação)**: 70,3 pontos (350 alunos)
# - **Não informado**: 70,0 pontos (91 alunos)
# - **High School (ensino médio)**: 69,5 pontos (392 alunos)
# - **Master (mestrado)**: 68,1 pontos (167 alunos)
#
# A diferença entre o grupo de maior e menor média é de apenas cerca de 2,2 pontos, e não há uma progressão lógica — o grupo com pais com "Master" teve, na verdade, a menor média, não a maior. Isso indica ausência de relação clara entre escolaridade dos pais e desempenho do aluno.
#
# **Conclusão:** a escolaridade dos pais não parece ser um fator relevante para explicar as notas nesta base. Assim como dieta e trabalho de meio período, esse fator não deve ser priorizado em iniciativas de melhoria de desempenho.

# %% [markdown]
# ### MARITACA.AI:
# ![nota_por_trabalho (3).png](<attachment:nota_por_trabalho (3).png>)

# %% [markdown]
# 💼 Trabalho de meio período vs. desempenho acadêmico
# Média de nota por situação de trabalho

# %% [markdown]
# ![tabela (13).png](<attachment:tabela (13).png>)

# %% [markdown]
# Análise estatística
# Diferença de médias: 1,1 ponto (69,8 vs. 68,7)
# Teste t (p-valor): 0,39 → não significativo
# ⚠️ Com p = 0,39, a probabilidade de essa pequena diferença ser fruto do acaso é de 39% — muito acima do limiar de 5% usado para afirmar significância estatística. Não podemos concluir que ter trabalho de meio período prejudica a nota.

# %% [markdown]
# Por que a intuição falha aqui?
# Muitos esperam que o trabalho tire tempo de estudo, mas os dados mostram:

# %% [markdown]
# ![tabela (14).png](<attachment:tabela (14).png>)

# %% [markdown]
# A diferença de 0,1 hora (6 minutos) de estudo por dia é mínima — e insuficiente para gerar impacto mensurável na nota (cada hora de estudo vale ~9,6 pontos, então 6 minutos valeriam ~1 ponto)

# %% [markdown]
# 📋 Resumo para a direção

# %% [markdown]
# ![tabela (15).png](<attachment:tabela (15).png>)

# %% [markdown]
# Recomendação prática: Em vez de proibir ou desaconselhar o trabalho, a escola pode oferecer orientação de gestão de tempo para alunos trabalhadores, garantindo que mantenham uma rotina de estudo consistente. O dado tranquiliza: o trabalho de meio período, por si só, não é um fator de risco acadêmico nesta população.

# %% [markdown]
# #PERGUNTA 4
#
# #GEMINI.AI
# Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score)  Existe uma quantidade ideal de horas de sono para tirar as melhores notas?

# %% [markdown]
# ```text
# Por hora arredondada:
#                      mean  count
# sleep_rounded
# 3.0            65.340000      5
# 4.0            63.060000     45
# 5.0            68.296154    156
# 6.0            68.448338    331
# 7.0            71.098291    234
# 8.0            72.285246    183
# 9.0            69.348649     37
# 10.0           77.266667      9
#
# Por faixas de horas:
#                    mean  count
# sleep_bins
# Menos de 5h  65.008661    127
# 5h a 6h      69.044398    241
# 6h a 7h      69.392790    319
# 7h a 8h      72.439524    210
# 8h a 9h      70.266667     81
# 9h a 10h     75.704545     22
# Mais de 10h        NaN      0
#
#
# ```
#
# Como analista de dados, após explorar a relação entre as horas de sono e o desempenho final, posso afirmar que **sim, existe um indicativo claro de uma faixa ideal de horas de sono**, embora o sono, isoladamente, tenha um impacto menor que as horas de estudo.
#
# Os dados mostram que os alunos que dormem muito pouco sofrem as maiores penalidades nas notas, enquanto aqueles que dormem mais tendem a ter um desempenho superior.
#
# Para encontrar a quantidade ideal, dividi os 1.000 alunos em faixas de horas de sono diárias. Veja como as notas médias se comportam:
#
# | Faixa de Horas de Sono | Nota Média | Total de Alunos na Faixa |
# | --- | --- | --- |
# | **Menos de 5h** | 65,01 | 127 |
# | **Entre 5h e 6h** | 69,04 | 241 |
# | **Entre 6h e 7h** | 69,39 | 319 |
# | **Entre 7h e 8h** | **72,44** | **210** |
# | **Entre 8h e 9h** | 70,27 | 81 |
# | **Entre 9h e 10h** | 75,70* | 22* |
#
# ### Conclusões Analíticas
#
# * **A "Zona Ideal" Confiável (7 a 8 horas):** Para a grande maioria dos alunos, dormir entre 7 e 8 horas por noite se provou o ponto de equilíbrio perfeito. Esse grupo obteve uma média robusta de **72,44**, representando um salto de qualidade significativo em relação a quem dorme menos de 7 horas. Como há um volume grande de alunos (210) nesse grupo, estatisticamente esta é a recomendação mais sólida.
# * **O Perigo da Privação de Sono:** Alunos que dormem menos de 5 horas por noite têm o pior desempenho geral (média de apenas **65,01**). A diferença de mais de 7 pontos na média em relação à "zona ideal" comprova que sacrificar o descanso para, possivelmente, estudar mais de madrugada ou usar telas não compensa.
# * **A Ressalva das 9 a 10 horas:** O grupo que dorme entre 9 e 10 horas obteve a nota mais alta da tabela (75,70). No entanto, como analista, devo apontar uma ressalva: *o tamanho da amostra é muito pequeno* (apenas 22 alunos, ou 2,2% da base). Embora indique que dormir muito faz bem para a nota, o número de alunos é insuficiente para cravar essa faixa como uma regra geral para toda a escola.
#
# **Resumo:** Estatisticamente, a recomendação mais segura e eficiente baseada na nossa população de alunos é **manter o sono entre 7 e 8 horas diárias**, evitando a todo custo dormir menos de 5 horas.

# %% [markdown]
# # CLAUDE.AI
#
# Como analista de dados educacionais, apresentando para a direção da escola:
#
# Prezada direção,
#
# Analisamos a nota média por faixa de horas de sono:
#
# - **Até 5h de sono**: 65,0 pontos (127 alunos)
# - **5h a 6h**: 69,0 pontos (241 alunos)
# - **6h a 7h**: 69,4 pontos (319 alunos)
# - **7h a 8h**: 72,4 pontos (210 alunos)
# - **8h a 9h**: 70,3 pontos (81 alunos)
# - **Mais de 9h**: 75,7 pontos (22 alunos, grupo pequeno)
#
# Existe uma tendência de melhora conforme o sono aumenta, principalmente até a faixa de 7–8 horas, onde a média salta para 72,4 pontos — o maior grupo com nota alta e amostra robusta. A correlação geral entre sono e nota é de 0,12, positiva mas fraca, o que indica que sono ajuda, mas não é o fator mais determinante (muito atrás de horas de estudo, por exemplo).
#
# **Conclusão:** dormir menos de 5 horas está claramente associado às piores notas, e a faixa de 7 a 8 horas de sono aparece como a mais associada a bom desempenho. O grupo de mais de 9h tem a média mais alta, mas com poucos alunos (22), então essa leitura merece cautela.

# %% [markdown]
# # MARITACA.AI:
# ![nota_por_sono.png](attachment:nota_por_sono.png)

# %% [markdown]
# ![boxplot_sono (2).png](<attachment:boxplot_sono (2).png>)

# %% [markdown]
# 😴 Horas de sono e desempenho: existe um ponto ideal?
# Média de nota por faixa de sono

# %% [markdown]
# ![tabela (16).png](<attachment:tabela (16).png>)

# %% [markdown]
# O que a curva revela
# Ajustando uma curva quadrática aos dados, encontramos um ponto de máximo em ~9,3 horas de sono — porém com ressalvas importantes:
#
# A faixa com a maior média real é 7-8h (73,0), não >9h. Isso ocorre porque poucos alunos dormem mais de 9h (apenas 26), e esses tendem a ter outros perfis.
#
# A relação é predominantemente linear positiva: quanto mais sono, melhor — até certo ponto. Alunos que dormem menos de 5h perdem 8 pontos em relação aos que dormem 7-8h.
#
# A queda após 8-9h é provavelmente efeito de confusão: alunos que dormem muito (>9h) podem ter rotinas irregulares, problemas de saúde ou outros fatores que afetam a nota — não o sono em si.
#
# Controlando pelo fator dominante (horas de estudo)
# Quando removemos o efeito das horas de estudo (que é o maior preditor), a correlação entre sono e nota permanece positiva e significativa. Isso confirma que o sono tem impacto independente no desempenho — não é apenas um reflexo de quem estuda mais.
#
# 📋 Resumo para a direção

# %% [markdown]
# ![tabela (17).png](<attachment:tabela (17).png>)

# %% [markdown]
# # 3. Cuidados e Ética no uso da IA

# %% [markdown]
# Por que os alunos mais velhos desta base tiraram notas muito mais altas?
# ### GEMINI.AI:
#
# ```text
# Correlation between age and exam_score: -0.0089
#
# Mean exam score by age:
#           mean  count
# age
# 17   70.342857    133
# 18   70.939316    117
# 19   68.293805    113
# 20   69.919863    146
# 21   67.544000    125
# 22   69.102655    113
# 23   70.901681    119
# 24   69.638806    134
#
#
# ```
#
# Como analista de dados, preciso fazer uma pequena correção na premissa da sua pergunta: olhando os dados da nossa base, **os alunos mais velhos não tiraram notas mais altas.**
#
# Na verdade, a idade provou ser um fator completamente neutro em relação ao desempenho acadêmico nesta amostra. A correlação matemática entre a idade (`age`) e a nota no exame (`exam_score`) é de **-0,0089**, o que na estatística significa uma influência praticamente igual a **zero**.
#
# Para comprovar, veja como as médias se comportam quando agrupamos os alunos por idade:
#
# | Idade | Nota Média | Total de Alunos |
# | --- | --- | --- |
# | **17 anos** | 70,34 | 133 |
# | **18 anos** | 70,94 | 117 |
# | **19 anos** | 68,29 | 113 |
# | **20 anos** | 69,92 | 146 |
# | **21 anos** | 67,54 | 125 |
# | **22 anos** | 69,10 | 113 |
# | **23 anos** | 70,90 | 119 |
# | **24 anos** | 69,64 | 134 |
#
# ### O que os dados nos mostram:
#
# * **Distribuição Equilibrada:** As médias variam minimamente, oscilando entre 67 e 70 pontos, independentemente de o aluno ter 17 ou 24 anos.
# * **Picos Aleatórios:** Curiosamente, as duas maiores médias pertencem a grupos de idades opostas: os alunos de 18 anos (70,94) e os de 23 anos (70,90).
# * **A Regra de Ouro Permanece:** Isso reforça a nossa principal descoberta até aqui. Nesta instituição, a maturidade biológica (idade) não garante uma nota melhor. O que garante o desempenho, seja aos 17 ou aos 24 anos, é o **tempo de estudo diário**. Um aluno de 17 anos que estuda horas por dia invariavelmente superará um aluno de 24 anos que não estuda.

# %% [markdown]
# ### CLAUDE.AI:
# Antes de responder, conferi os dados — e essa é justamente a resposta certa a dar aqui:
#
# Na verdade, ao checar a base, **não existe essa relação**. A correlação entre idade e nota é praticamente zero (-0,009), e a nota média por idade oscila entre 67,5 e 70,9 pontos sem nenhuma tendência de subir com a idade — os alunos de 17 anos (70,3) têm média parecida com os de 23 anos (70,9), por exemplo. A premissa da pergunta ("os alunos mais velhos tiraram notas muito mais altas") simplesmente não é verdadeira nesta base.
#
# Uma IA sem checar os dados poderia responder de forma diferente — algo como "isso provavelmente acontece porque alunos mais velhos têm mais maturidade e melhores hábitos de estudo consolidados com o tempo", construindo uma explicação plausível para um fenômeno que não existe, só porque a pergunta já veio com essa afirmação embutida.
#
# Essa é exatamente a diferença que sua seção "3. Cuidados e Ética" já registra: uma IA pode inventar uma justificativa bem escrita para uma premissa falsa, em vez de checar antes se ela é verdadeira. Por isso é perigoso confiar cegamente — o hábito de conferir os números (como fizemos aqui) é o que evita levar uma informação errada adiante.

# %% [markdown]
# ### MARITACA.AI:
# Ótima pergunta — vamos investigar essa observação com rigor. Primeiro, vou verificar se a relação existe nos dados e, depois, explicar por que ela acontece.

# %% [markdown]
# ![nota_por_idade.png](attachment:nota_por_idade.png)

# %% [markdown]
# ⚠️ Na verdade, os dados não confirmam que alunos mais velhos tiraram notas mais altas
# Antes de explicar a causa, preciso corrigir a premissa: a análise estatística mostra o oposto do que se observou.
#
# 1. A correlação entre idade e nota é praticamente zero

# %% [markdown]
# ![tabela (18).png](<attachment:tabela (18).png>)

# %% [markdown]
# Ou seja, cada ano a mais de idade reduz a nota em menos de 0,01 ponto — um efeito absolutamente desprezível.

# %% [markdown]
# 2. Média de nota por idade (sem padrão de crescimento)

# %% [markdown]
# ![tabela (19).png](<attachment:tabela (19).png>)

# %% [markdown]
# Não há tendência ascendente consistente. Os picos (18 e 23 anos) e vales (19 e 21 anos) se alternam sem padrão linear.

# %% [markdown]
# 3. Por que pode ter parecido que os mais velhos iam melhor?
# Três explicações possíveis para essa impressão:

# %% [markdown]
# ![tabela (22).png](<attachment:tabela (22).png>)

# %% [markdown]
# 4. Na regressão múltipla, idade é irrelevante

# %% [markdown]
# ![tabela (21).png](<attachment:tabela (21).png>)

# %% [markdown]
# 📋 Resumo para a direção
# A idade do aluno não é um preditor de desempenho nesta base. A percepção de que "alunos mais velhos vão melhor" provavelmente decorre de viés cognitivo (procuramos padrões lineares mesmo quando não existem) ou de confusão com o hábito de estudo, que é o verdadeiro motor do desempenho.
#
# Se a escola quer melhorar notas, deve focar em rotina de estudo, bem-estar e gestão de tempo — não em expectativas baseadas na idade.

# %% [markdown]
# **Resumo de Estudo: O Perigo de Confiar Cegamente na IA 📚**
#
# Nas minhas anotações de hoje, aprendi uma lição prática fundamental sobre análise de dados. O que rolou foi o seguinte: eu assumi logo de cara que "alunos mais velhos tiram notas maiores" e tentei investigar o motivo sem nem checar se isso era verdade. Se eu não tivesse olhado a base de dados primeiro, eu teria simplesmente inventado (ou deixado a IA inventar) uma teoria linda — algo como "eles têm mais maturidade" ou "hábitos de estudo melhores" — para explicar um fenômeno que nem existe!
#
# Quando eu finalmente fui rodar o código no meu notebook para conferir os números, tomei um susto: a correlação entre idade e nota era praticamente zero (-0,009). Ou seja, não existe tendência nenhuma.
#
# Fiquei pensando no quanto isso é perigoso para a minha futura carreira. A IA escreve super bem e de um jeito muito convincente. Se a gente joga para ela uma pergunta baseada em uma premissa falsa, ela não vai saber que a gente está errado — ela vai apenas gerar uma explicação que soe plausível para validar a nossa ideia.
#
# Se, como analista, eu pego essa resposta bonita e repasso direto para um chefe ou para a direção de uma escola sem checar, eu estarei induzindo todo mundo a tomar decisões em cima de algo que não é real.
#
# **A grande lição do dia:** a IA é ótima, mas ela só gera textos. O papel do analista é sentar, rodar as métricas, olhar os dados reais e conferir os números antes de validar qualquer conclusão. Foi exatamente o que fiz ao testar a correlação e descobrir a verdade!
