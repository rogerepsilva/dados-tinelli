# %% [markdown]
# abrir terminal lá em baixo ( ctrl + ')

# %%
#Importação de biblioteca
import numpy as np #"np será o apelido"

# %%
temperaturas = np.array([30,40,50,60,100])
print(temperaturas)
print (type(temperaturas))
# Out:
# [ 30  40  50  60 100]
# <class 'numpy.ndarray'>

# %%
#média aritimética
media = np.mean(temperaturas)
print(f"[{media:.2f}")
# Out:
# [56.00

# %%
#Retorna o maior valor
maior_valor =np.max(temperaturas)
print(maior_valor)
# Out:
# 100

# %%
menor_valor = np.min(temperaturas)
print(menor_valor)
# Out:
# 30

# %%
#Salários x 1000
salarios = np.array([2,3,4,5,1,500])
media_salarios = np.mean (salarios)
print (media_salarios)
# Out:
# 85.83333333333333

# %%
mediana = np.median(salarios)
print(mediana)
# Out:
# 3.5

# %% [markdown]
# #Desafio
# - criar array de hab de 5 cidades sp
# maior populacao
# menor populacao
# media de populacao
# mediana
# maior_populacaosp = Sao Paulo 11451245 guarulhos 1291784 campinas 1138309 sao bernardo do campo 810729 santo andre 748919
# menor_populacaosp = bora 907 nova castilho 1062 uru 1370 flora rica 1487 uniao paulista 1535
# media_populacao
# media

# %%
populacao = np.array([11451245,1291784,1138309,810729,748919,907,1062,1370,1487,1535])
print(populacao)
print (type(populacao))
# Out:
# [11451245  1291784  1138309   810729   748919      907     1062     1370
#      1487     1535]
# <class 'numpy.ndarray'>

# %%
#média aritimética
media = np.mean(populacao)
print(f"{media:.3f}") # como colocar . de milhar??
# Out:
# 1544734.700

# %%
#Retorna o maior valor
maior_valor =np.max(populacao)
print(maior_valor)
# Out:
# 11451245

# %%
menor_valor = np.min(populacao)
print(menor_valor)
# Out:
# 907

# %%
mediana = np.median(populacao)
print(mediana)
# Out:
# 375227.0
